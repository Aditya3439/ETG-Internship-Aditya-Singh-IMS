# %% [markdown]
# # Reading Data From JSON File

# %%
import json
fd = open("items.json",'r')
r = fd.read()
fd.close()
records={}
records = json.loads(r)
records
# Out:
# {'12300': {'name': 'Pasta',
#   'price': 20,
#   'quantity': 50,
#   'expiry_date': '6 months',
#   'brand': 'Yippee Pasta treat'},
#  '12301': {'name': 'Cooking Oil',
#   'price': 135,
#   'quantity': 100,
#   'expiry_date': 'Aug 2022',
#   'brand': 'Saffolla low Clasterol oil'},
#  '12302': {'name': 'Milk',
#   'price': 21,
#   'quantity': 200,
#   'expiry_date': '5 days',
#   'brand': 'Amul Milk'},
#  '12303': {'name': 'Bread',
#   'price': 25,
#   'quantity': 50,
#   'expiry_date': '1 day',
#   'brand': 'Bonn Brown Bread'},
#  '12304': {'name': 'Salt',
#   'price': 30,
#   'quantity': 60,
#   'expiry_date': 'Dec 2022',
#   'brand': 'Tata Salt'},
#  '12305': {'name': 'Sugar',
#   'price': 50,
#   'quantity': 60,
#   'expiry_date': 'Sept 2022',
#   'brand': 'Madhur Pure and Hygienic Sugar'},
#  '12306': {'name': 'Butter',
#   'price': 10,
#   'quantity': 25,
#   'expiry_date': '3 months',
#   'brand': 'Amul Butter'},
#  '12307': {'name': 'Cheese',
#   'price': 25,
# ...

# %% [markdown]
# # Adding New Products to the Inventory

# %%
prod_id = str(input("Enter Product's id:"))
prod_name = str(input("Enter Name of the product:"))
prod_price = int(input("Enter Product's Price:"))
prod_quantity = int(input("Enter Product's Qunatity:"))
prod_expiry_date = str(input("Enter Product's Expiry Date:"))
prod_brand = str(input("Enter Product's Brand:"))
for i in records:
    if i == prod_id:
        records[i]["quantity"] = records[i]["quantity"] + prod_quantity
        js = json.dumps(record)
        fd = open("items.json",'w')
        fd.write(js)
        fd.close()
    else:
        records[prod_id] = {'name': prod_name, 'price': prod_price, 'quantity': prod_quantity, 'expiry_date': prod_expiry_date, 'brand': prod_brand}
        js = json.dumps(record)
        fd = open("items.json",'w')
        fd.write(js)
        fd.close()
# Out:
# Enter Product's id:12327
# Enter Name of the product:Tooth Paste
# Enter Product's Price:55
# Enter Product's Qunatity:50
# Enter Product's Expiry Date:Aug 2023
# Enter Product's Brand:Colgate

# %%
records
# Out:
# {'12300': {'name': 'Pasta',
#   'price': 20,
#   'quantity': 50,
#   'expiry_date': '6 months',
#   'brand': 'Yippee Pasta treat'},
#  '12301': {'name': 'Cooking Oil',
#   'price': 135,
#   'quantity': 100,
#   'expiry_date': 'Aug 2022',
#   'brand': 'Saffolla low Clasterol oil'},
#  '12302': {'name': 'Milk',
#   'price': 21,
#   'quantity': 200,
#   'expiry_date': '5 days',
#   'brand': 'Amul Milk'},
#  '12303': {'name': 'Bread',
#   'price': 25,
#   'quantity': 50,
#   'expiry_date': '1 day',
#   'brand': 'Bonn Brown Bread'},
#  '12304': {'name': 'Salt',
#   'price': 30,
#   'quantity': 60,
#   'expiry_date': 'Dec 2022',
#   'brand': 'Tata Salt'},
#  '12305': {'name': 'Sugar',
#   'price': 50,
#   'quantity': 60,
#   'expiry_date': 'Sept 2022',
#   'brand': 'Madhur Pure and Hygienic Sugar'},
#  '12306': {'name': 'Butter',
#   'price': 10,
#   'quantity': 25,
#   'expiry_date': '3 months',
#   'brand': 'Amul Butter'},
#  '12307': {'name': 'Cheese',
#   'price': 25,
# ...
